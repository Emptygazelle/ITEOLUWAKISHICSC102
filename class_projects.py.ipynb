# %% [markdown]
# **NAME** :Iteoluwakishi Olamide Opaleye
# **Email** :Iteoluwakishi.opaleye@pau.edu.ng
# **Matric. No.**:
#
#
# # Project 1
#
# To develop an algorithm (pseudocode) and python program to get the differnece between a given number and 17, if the number is greater than 17 returns double the absolute difference.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Pseudocode
#
# **INPUT** x
#
# **INPUT** 17
#
# **COMPUTE** z = x-17
#
# **IF** z>17
#
# **PRINT** ((abs(z)*2))
#
# **ELSE**
#
# **PRINT** (Z*2)

# %%
x = int(input("Insert a number"))
z = int(x-17)
d = abs(z)*2
if x>17:
    print(z)
else:
    print(x*2)
# Out:
# Insert a number 19
# 2

# %% [markdown]
# # Project 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Pseudocode
#
# **INPUT** x
#
# **INPUT** y
#
# **INPUT** z
#
# **COMPUTE** d = x+y+z
#
# **IF** x=y=z
#
# **PRINT** (d*3)
#
# **ELSE**
#
# **PRINT d**

# %%
x = int(input("Insert a number"))
y = int(input("Insert another number"))
z = int(input("Insert another number")) 
d = int(x+y+z)
if x==y==z:
    print(d*3)
else:
    print(x+y+z)
# Out:
# Insert a number8
# Insert another number8
# Insert another number8
# 72

# %% [markdown]
# # Project 3
#
# To develop the algorithm (pseudocode) and python program which will return true if the two given integer values are equal or their sum/difference is 5
#
# ![image.png](attachment:image.png)
#
# ## Pseudocode
#
# **INPUT** x
#
# **INPUT** y
#
# **IF** x=y
#
# **PRINT** **TRUE**
#
# **ELIF** x-y=5
#
# **PRINT** **TRUE**
#
# **ELIF** x+y=5
#
# **PRINT** **TRUE**
#
# **ELSE**
#
# **PRINT** **FALSE**

# %%
x = int(input("Insert a number"))
y = int(input("insert a number"))
if x==y:
    print("True")
elif x-y== 5:
    print("True")
elif x+y==5:
    print("True")
else:
    print("False")
# Out:
# Insert a number 4
# insert a number 9
# False

# %% [markdown]
# # Project 4
#
# Develop the algorithm and python program to sort three integers without using conditional statements and loops
#
# ![image-2.png](attachment:image-2.png)
#
#
# ## Pseudocode
#
# **INPUT** x
#
# **INPUT** y
#
# **INPUT** z
#
# **COMPUTE** List=[x,y,z]
#
# **COMPUTE** m=(x+y+z-Max. value-Min. value)
#
# **PRINT** Max value,m and Min Value

# %%
x = int(input("Insert a number"))
y = int(input("Insert a number"))
z= int(input("Insert a number"))
list = [x,y,z]
m = int(x+y+z-max(list)-min(list))
print(max(list),m,min(list))
# Out:
# Insert a number19
# Insert a number17
# Insert a number20
# 20 19 17

# %% [markdown]
# # Project 5
#
# To develop an algorithm and python function that takes a positive integer and returns the sum of cube of all the positive integers smaller than the specified number

# %%
i = int(input("value of i: "))
x = i-1
while 0 < x:
    print (x*x)
    x = x - 1
# Out:
# value of i: 100
# 9801
# 9604
# 9409
# 9216
# 9025
# 8836
# 8649
# 8464
# 8281
# 8100
# 7921
# 7744
# 7569
# 7396
# 7225
# 7056
# 6889
# 6724
# 6561
# 6400
# 6241
# 6084
# 5929
# 5776
# 5625
# 5476
# 5329
# 5184
# 5041
# 4900
# 4761
# 4624
# 4489
# 4356
# 4225
# 4096
# 3969
# 3844
# 3721
# 3600
# 3481
# 3364
# 3249
# 3136
# 3025
# 2916
# 2809
# 2704
# 2601
# 2500
# 2401
# 2304
# 2209
# 2116
# 2025
# 1936
# 1849
# 1764
# 1681
# 1600
# 1521
# 1444
# 1369
# 1296
# 1225
# 1156
# 1089
# 1024
# 961
# 900
# 841
# 784
# 729
# 676
# 625
# 576
# 529
# 484
# 441
# 400
# 361
# 324
# 289
# 256
# 225
# 196
# 169
# 144
# 121
# 100
# 81
# 64
# 49
# 36
# 25
# 16
# 9
# 4
# 1
